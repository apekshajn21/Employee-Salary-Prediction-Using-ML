# %% [markdown]
# ---

# %% [markdown]
# # CAPSTONE PROJECT

# %% [markdown]
# ### TOPIC: Employee Salary Prediction using
# 1. linear regression
# 2. Support Vector Regression
# 3. Random Forest Regression

# %% [markdown]
# **LOAD THE DATASET**

# %%
import pandas as pd
from pandas import DataFrame as df

#load the dataset
df=pd.read_csv('employee_attrition_data.csv',sep='\t')

# %%
print (df)
# Out:
#     Employee_ID,Age,Gender,Department,Job_Title,Years_at_Company,Satisfaction_Level,Average_Monthly_Hours,Promotion_Last_5Years,Salary,Attrition
# 0    0,27,Male,Marketing,Manager,9,0.58625125624761...
# 1    1,53,Female,Sales,Engineer,10,0.26116088945025...
# 2    2,59,Female,Marketing,Analyst,8,0.304381717512...
# 3    3,42,Female,Engineering,Manager,1,0.4807788698...
# 4    4,44,Female,Sales,Engineer,10,0.63624388759598...
# ..                                                 ...
# 995  995,39,Female,HR,HR Specialist,3,0.37743486613...
# 996  996,50,Male,Engineering,Manager,1,0.4311521320...
# 997  997,52,Male,Engineering,Analyst,3,0.6471024872...
# 998  998,37,Female,HR,HR Specialist,2,0.30481271490...
# 999  999,59,Male,Sales,HR Specialist,1,0.9405101237...
#
# [1000 rows x 1 columns]

# %%
print("\n from head")
print(df.head(10))  # Show the first 10 rows of the dataset
print("\n \n from tail")
print(df.tail(10))  # Show the last 10 rows of the dataset
print("\n \n Columns in the dataset:")
print(df.columns)  # Show the column names of the dataset
print("\n \n Summary of each column:")
df.info()  # Show a concise summary of the DataFrame
# Out:
#  from head
#   Employee_ID,Age,Gender,Department,Job_Title,Years_at_Company,Satisfaction_Level,Average_Monthly_Hours,Promotion_Last_5Years,Salary,Attrition
# 0  0,27,Male,Marketing,Manager,9,0.58625125624761...
# 1  1,53,Female,Sales,Engineer,10,0.26116088945025...
# 2  2,59,Female,Marketing,Analyst,8,0.304381717512...
# 3  3,42,Female,Engineering,Manager,1,0.4807788698...
# 4  4,44,Female,Sales,Engineer,10,0.63624388759598...
# 5  5,47,Male,Sales,HR Specialist,10,0.88901766902...
# 6  6,58,Male,Marketing,HR Specialist,5,0.68897657...
# 7  7,57,Female,Sales,Analyst,8,0.9816786912170571...
# 8  8,34,Female,Finance,Accountant,6,0.01038090172...
# 9  9,57,Female,Marketing,Engineer,7,0.46678235968...
#
#
#  from tail
#     Employee_ID,Age,Gender,Department,Job_Title,Years_at_Company,Satisfaction_Level,Average_Monthly_Hours,Promotion_Last_5Years,Salary,Attrition
# 990  990,36,Female,Engineering,Accountant,9,0.55851...
# 991  991,47,Male,Marketing,Manager,2,0.889620756646...
# ...

# %% [markdown]
# **Check the missing values**

# %%
df.isna()# Check for missing values in the DataFrame

print("\nCount of missing values in each column:")
df.isna().sum() # Count the number of missing values in each column
# Out:
# Count of missing values in each column:
# Employee_ID,Age,Gender,Department,Job_Title,Years_at_Company,Satisfaction_Level,Average_Monthly_Hours,Promotion_Last_5Years,Salary,Attrition    0
# dtype: int64

# %% [markdown]
# **Check for duplicate Values**

# %%
df.duplicated()  # Check for duplicate rows in the DataFrame
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# **Remove Unwanted Columns**

# %%
print(df.head())
# Out:
#   Employee_ID,Age,Gender,Department,Job_Title,Years_at_Company,Satisfaction_Level,Average_Monthly_Hours,Promotion_Last_5Years,Salary,Attrition
# 0  0,27,Male,Marketing,Manager,9,0.58625125624761...
# 1  1,53,Female,Sales,Engineer,10,0.26116088945025...
# 2  2,59,Female,Marketing,Analyst,8,0.304381717512...
# 3  3,42,Female,Engineering,Manager,1,0.4807788698...
# 4  4,44,Female,Sales,Engineer,10,0.63624388759598...

# %%
df.columns
# Out:
# Index(['Employee_ID,Age,Gender,Department,Job_Title,Years_at_Company,Satisfaction_Level,Average_Monthly_Hours,Promotion_Last_5Years,Salary,Attrition'], dtype='object')

# %%
import pandas as pd

df = pd.read_csv('employee_attrition_data.csv')   # Replace with correct path

# Clean column names
df.columns = df.columns.str.strip()

# Drop column safely
df = df.drop(columns=['Employee_ID'])

# %%
df.head()# Remove unwanted columns
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %% [markdown]
# **Gender Count Of Employees**

# %%
import matplotlib.pyplot as plt

# %%
df["Gender"].value_counts().plot(kind='bar', color=['blue', 'pink'])
plt.title("Gender Count of Employees")
plt.ylabel("Count")
plt.xlabel("Gender")
plt.show()

# %% [markdown]
# high salary job titles

# %% [markdown]
# **Grouping using job title**

# %%
df.groupby('Job_Title').size().sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: >

# %% [markdown]
# **Grouping using Job Title and salary**

# %%
df.groupby('Job_Title')['Salary'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title("Average Salary by Job Title")
plt.ylabel("Average Salary")
plt.xlabel("Job Title")
plt.show()

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.title('Average Salary By Job Title')
plt.xlabel('Job Title')
plt.ylabel('Average Salary')
plt.grid(True)
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
df.columns  # Display the columns of the DataFrame
# Out:
# Index(['Age', 'Gender', 'Department', 'Job_Title', 'Years_at_Company',
#        'Satisfaction_Level', 'Average_Monthly_Hours', 'Promotion_Last_5Years',
#        'Salary', 'Attrition'],
#       dtype='object')

# %%
x=df[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y=df["Salary"]
print(x)
print(y)
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]
# 0      60132
# 1      79947
# 2      46958
# 3      40662
# 4      74307
#        ...
# 995    71403
# 996    30181
# 997    64143
# 998    74383
# 999    73220
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train=scaler.fit_transform(x)

# %%
x_train
# Out:
# array([[ 1.20355456,  0.27707872, -1.63733175],
#        [ 1.55806253, -0.84527027,  0.7261686 ],
#        [ 0.84904659, -0.69605375, -0.52311016],
#        ...,
#        [-0.92349326,  0.48716282,  0.21970424],
#        [-1.27800123, -0.69456577,  1.40145442],
#        [-1.6325092 ,  1.50012967, -1.36721743]])

# %% [markdown]
# **JOBLIB is a Python library for efficient serialization, parallel processing, and caching, especially for large NumPy arrays and scikit-learn models.**

# %%
import joblib
joblib.dump(scaler, 'scaler.pkl')  # Save the scaler for future use
# Out:
# ['scaler.pkl']

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 0.47597324,  1.30983557,  0.33822898],
#        [ 1.19442342, -1.72064442, -0.91203378],
#        [ 1.55364851, -0.41804212, -0.05659084],
#        [ 1.55364851, -1.7959776 , -1.10944369],
#        [-0.24247694, -0.56605424, -1.10944369],
#        [ 0.83519833,  0.94451894, -1.5042635 ],
#        [ 0.47597324, -0.43212457, -1.5042635 ],
#        [ 0.47597324,  0.87641335,  1.48978678],
#        [-0.24247694,  0.10446999, -1.57006681],
#        [-0.24247694,  0.53445167,  1.45688512],
#        [ 0.83519833, -0.5658673 ,  0.50273723],
#        [ 0.11674815,  1.18744793, -0.55011561],
#        [ 0.83519833,  0.40748739, -0.58301726],
#        [ 0.47597324, -1.10009824,  1.58849173],
#        [ 0.47597324,  0.09453447,  0.07501577],
#        [-1.67937729,  0.28111418, -1.47136185],
#        [-0.96092711, -1.73083212,  0.83175375],
#        [ 1.19442342,  1.37039705,  0.89755705],
#        [ 0.47597324,  0.40164366, -1.20814864],
#        [-1.3201522 , -0.49251488,  0.89755705],
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
def results(predictions):
    print("Mean Absolute Error on model is{}", format(mean_absolute_error(y_test, predictions)))
    print("Root Mean Squared Error on model is{}", format(np.sqrt(mean_squared_error(y_test, predictions))))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load the data
df = pd.read_csv('employee_attrition_data.csv', sep=',')


# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Train Linear Regression model
lr = LinearRegression()
lr.fit(x_train, y_train)

# Check model score (optional)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(x_test)
results(predictions)
# Out:
# Mean Absolute Error on model is{} 18474.12873935999
# Root Mean Squared Error on model is{} 21146.089661684655

# %% [markdown]
# ## SVR

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr = {
    'C': [0.1, 1, 10],
    'epsilon': [0.1, 0.2, 0.5],
    'kernel': ['linear', 'poly', 'rbf'], #ensure valid kernel types
    'degree': [2, 3, 4], #only apllicable if poly kernel is used
}

# %%
gridsvr=GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(x_train, y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 0.1, 'degree': 2, 'epsilon': 0.5, 'kernel': 'linear'}

# %%
predictions=gridsvr.predict(x_test)
results(predictions)
# Out:
# Mean Absolute Error on model is{} 18513.98303229362
# Root Mean Squared Error on model is{} 21179.304694862913

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
numeric_f=df.select_dtypes(include=np.number)
sns.heatmap(numeric_f.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# ## RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()

# %%
param_gridsvr={
    "n_estimators": [2,3,4,5,6], #use a list instead of a set
    "max_depth": [5, 10, 15], 
}

# %%
gridrfr=GridSearchCV(estimator=rfmodel, param_grid=param_gridsvr, cv=5)

# %%
gridrfr.fit(x_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 5}

# %%
predictionofrfr = gridrfr.predict(x_test)
results(predictionofrfr)
# Out:
# Mean Absolute Error on model is{} 18743.83291888402
# Root Mean Squared Error on model is{} 21702.356513161154

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr, 'model.pkl')  # Save the model for future use
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')

# %% [markdown]
# ## Plotting the accuracy graph

# %%
lr_score = lr.score(x_test, y_test)
svr_score = gridsvr.score(x_test, y_test)
rfr_score = gridrfr.score(x_test, y_test)

print("Linear Regression R^2 Score:", lr_score)
print("Support Vector Regression R^2 Score:", svr_score)
print("Random Forest Regression R^2 Score:", rfr_score)
# Out:
# Linear Regression R^2 Score: -0.007725654584044062
# Support Vector Regression R^2 Score: -0.01089389317845968
# Random Forest Regression R^2 Score: -0.06144125500266817

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Example: Load your data
# df = pd.read_csv("your_file.csv")
# X = df.drop("target_column", axis=1)
# y = df["target_column"]

# Assuming you already have X and y
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "SVM": SVR()
}

rmse_scores = {}

# Train and evaluate
for name, model in models.items():
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores[name] = rmse
    print(f"{name} RMSE: {rmse:.2f}")

# Plot RMSE comparison
plt.figure(figsize=(8, 5))
plt.bar(rmse_scores.keys(), rmse_scores.values(), color=['skyblue', 'lightgreen', 'lightcoral'])
plt.title("RMSE Comparison of Models")
plt.ylabel("Root Mean Squared Error")
plt.xlabel("Models")
plt.tight_layout()
plt.show()
# Out:
# Linear Regression RMSE: 21146.09
# Random Forest RMSE: 22999.45
# SVM RMSE: 21098.66
